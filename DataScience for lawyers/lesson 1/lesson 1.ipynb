# %% [markdown]
# # Задание 1

# %%
"""1.1 создание переменных"""
print('введите число')
a = int(input())
print ('введите строку')
b = str(input())
id(a)
id(b)
# Out:
# введите число
# введите строку
# 1632844157776

# %%
"""1.2 время"""
print('введите время в секундах')
inputed = False
raw_input
while not inputed:
    raw_input = input()
    if raw_input.isdigit() == False:
        print('ошибка ввода, введите число')
    else:
        inputed = True

minutes = int(raw_input)/60
hours =minutes/60
seconds = raw_input
print(f"Часы {hours} Минуты {minutes} Секунды {seconds}")
# Out:
# введите время в секундах
# ошибка ввода, введите число

# %%
"""1.3 сумма n+nn+nnn"""
inputed = False
raw_input
while not inputed:
    print('введите число от 1 до 9')
    raw_input = input()
    if raw_input.isdigit() == False or (int(raw_input) > 9 or int(raw_input) < 1):
        print('ошибка ввода, введено не то')
    else:
        inputed = True

a = int(raw_input)
b = str(a)+str(a)
c= str(a)+str(a)+str(a)
bi =int(b)
ci =int(c)
sum = a+bi+ci
print(sum)
# Out:
# введите число от 1 до 9
# 123

# %%
"""1.4 задание повышенной сложности"""
member_list=[]
max_members = 3
for i in range(1 , max_members+1):
    print(f"Введите данные для участника {i}:")
    name = input("Наименование: ")
    status = input ("Статус: ")
    inn = input("ИНН: ")
    member={
        "name":name,
        "status":status,
        "inn":inn
    }
    member_list.append(member)
print(member_list)
# Out:
# Введите данные для участника 1:
# Введите данные для участника 2:
# Введите данные для участника 3:
# [{'name': '1', 'status': '2', 'inn': '3'}, {'name': 'gg', 'status': 'hh', 'inn': 'cc'}, {'name': 'g', 'status': 'u', 'inn': 'c'}]
